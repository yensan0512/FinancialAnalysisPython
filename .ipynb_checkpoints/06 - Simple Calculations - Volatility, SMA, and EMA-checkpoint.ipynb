# %% [markdown]
# # Calculating simple
# - Pct change
# - Log returns
# - Standard deviation (Volatility)
# - Rolling
#     - Simple Moving Avarage
#     - Exponential Moving Average

# %% [markdown]
# ### Standard deviation
#
# - $\sigma_{p} = \sigma_{daily}\times \sqrt{p}$
# - $\sigma_{annually} = \sigma_{daily}\times \sqrt{252}$
#
#     *(252 trading days per year)*

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
remote_file = "https://raw.githubusercontent.com/LearnPythonWithRune/FinancialDataAnalysisWithPython/main/files/AAPL.csv"
data = pd.read_csv(remote_file, index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400

# %%
data['%-chg'] = data['Close'].pct_change()

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400
#
#                %-chg
# Date
# 2020-01-27       NaN
# 2020-01-28  0.028289
# 2020-01-29  0.020932
# 2020-01-30 -0.001449
# 2020-01-31 -0.044339

# %%
(79.422501 - 77.237503)/77.237503
# Out:
# 0.028289340218572226

# %%
import numpy as np

# %%
data['Log returns'] = np.log(data['Close']/data['Close'].shift())

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400
#
#                %-chg  Log returns
# Date
# 2020-01-27       NaN          NaN
# 2020-01-28  0.028289     0.027897
# 2020-01-29  0.020932     0.020716
# 2020-01-30 -0.001449    -0.001450
# 2020-01-31 -0.044339    -0.045352

# %%
data['Close']/data['Close'].shift()
# Out:
# Date
# 2020-01-27         NaN
# 2020-01-28    1.028289
# 2020-01-29    1.020932
# 2020-01-30    0.998551
# 2020-01-31    0.955661
#                 ...
# 2021-01-20    1.032856
# 2021-01-21    1.036658
# 2021-01-22    1.016074
# 2021-01-25    1.027684
# 2021-01-26    0.994123
# Name: Close, Length: 253, dtype: float64

# %%
data['Close'].shift()
# Out:
# Date
# 2020-01-27           NaN
# 2020-01-28     77.237503
# 2020-01-29     79.422501
# 2020-01-30     81.084999
# 2020-01-31     80.967499
#                  ...
# 2021-01-20    127.830002
# 2021-01-21    132.029999
# 2021-01-22    136.869995
# 2021-01-25    139.070007
# 2021-01-26    142.919998
# Name: Close, Length: 253, dtype: float64

# %%
data['Close'].shift(2)
# Out:
# Date
# 2020-01-27           NaN
# 2020-01-28           NaN
# 2020-01-29     77.237503
# 2020-01-30     79.422501
# 2020-01-31     81.084999
#                  ...
# 2021-01-20    127.139999
# 2021-01-21    127.830002
# 2021-01-22    132.029999
# 2021-01-25    136.869995
# 2021-01-26    139.070007
# Name: Close, Length: 253, dtype: float64

# %%
data['Log returns'].std()
# Out:
# 0.02976380454385511

# %%
volatility = data['Log returns'].std()*252**.5

# %%
volatility
# Out:
# 0.4724857493650493

# %%
str_vol = str(round(volatility,4)*100)

# %%
str_vol
# Out:
# '47.25'

# %%
fig, ax = plt.subplots()
data['Log returns'].hist(ax=ax, bins=50, alpha=0.6, color='b')
ax.set_xlabel("Log return")
ax.set_ylabel("Freq of log return")
ax.set_title("AAPL volatility: " + str_vol + "%")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPL volatility: 47.25%')

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400
#
#                %-chg  Log returns
# Date
# 2020-01-27       NaN          NaN
# 2020-01-28  0.028289     0.027897
# 2020-01-29  0.020932     0.020716
# 2020-01-30 -0.001449    -0.001450
# 2020-01-31 -0.044339    -0.045352

# %%
# sum of 77.237503 + 79.422501
data['Close'].rolling(2).sum()
# Out:
# Date
# 2020-01-27           NaN
# 2020-01-28    156.660004
# 2020-01-29    160.507500
# 2020-01-30    162.052498
# 2020-01-31    158.345001
#                  ...
# 2021-01-20    259.860001
# 2021-01-21    268.899994
# 2021-01-22    275.940002
# 2021-01-25    281.990005
# 2021-01-26    285.000000
# Name: Close, Length: 253, dtype: float64

# %%
77.237503 + 79.422501
# Out:
# 156.66000400000001

# %%
# MA10 days,50 days
data['MA10'] = data['Close'].rolling(10).mean()
data['MA50'] = data['Close'].rolling(50).mean()

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400
#
#                %-chg  Log returns  MA10  MA50
# Date
# 2020-01-27       NaN          NaN   NaN   NaN
# 2020-01-28  0.028289     0.027897   NaN   NaN
# 2020-01-29  0.020932     0.020716   NaN   NaN
# 2020-01-30 -0.001449    -0.001450   NaN   NaN
# 2020-01-31 -0.044339    -0.045352   NaN   NaN

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-20  128.660004  132.490005  128.550003  132.029999  132.029999
# 2021-01-21  133.800003  139.669998  133.589996  136.869995  136.869995
# 2021-01-22  136.279999  139.850006  135.020004  139.070007  139.070007
# 2021-01-25  143.070007  145.089996  136.539993  142.919998  142.919998
# 2021-01-26  143.600006  144.300003  141.369995  142.080002  142.080002
#
#                Volume     %-chg  Log returns        MA10      MA50
# Date
# 2021-01-20  104319500  0.032856     0.032328  129.415000  124.7658
# 2021-01-21  120529500  0.036658     0.036002  130.442000  125.1294
# 2021-01-22  114459400  0.016074     0.015946  131.257001  125.5844
# 2021-01-25  157282400  0.027684     0.027308  132.344000  126.1234
# 2021-01-26   50388565 -0.005877    -0.005895  133.654001  126.5752

# %%
data['EMA10'] = data['Close'].ewm(span=10, adjust=False).mean()

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-20  128.660004  132.490005  128.550003  132.029999  132.029999
# 2021-01-21  133.800003  139.669998  133.589996  136.869995  136.869995
# 2021-01-22  136.279999  139.850006  135.020004  139.070007  139.070007
# 2021-01-25  143.070007  145.089996  136.539993  142.919998  142.919998
# 2021-01-26  143.600006  144.300003  141.369995  142.080002  142.080002
#
#                Volume     %-chg  Log returns        MA10      MA50       EMA10
# Date
# 2021-01-20  104319500  0.032856     0.032328  129.415000  124.7658  129.703820
# 2021-01-21  120529500  0.036658     0.036002  130.442000  125.1294  131.006761
# 2021-01-22  114459400  0.016074     0.015946  131.257001  125.5844  132.472806
# 2021-01-25  157282400  0.027684     0.027308  132.344000  126.1234  134.372295
# 2021-01-26   50388565 -0.005877    -0.005895  133.654001  126.5752  135.773696

# %%
fig, ax = plt.subplots()
data[['MA10','EMA10']].loc['2020-12-01':].plot(ax=ax)
data['Close'].loc['2020-12-01':].plot(ax=ax,alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>
