# %% [markdown]
# # Pandas-datareader
# - https://pandas-datareader.readthedocs.io/en/latest/

# %%
import pandas_datareader as pdr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21592\288088074.py in <module>
# ----> 1 import pandas_datareader as pdr
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
# !pip install pandas_datareader
# Out:
# ...
#      -------------------------------------- 109.5/109.5 kB 6.6 MB/s eta 0:00:00
# ...

# %%
pip install yfinance
# Out:
# ...
#      ---------------------------------------- 59.3/59.3 kB 3.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 499.4/499.4 kB 15.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 112.2/112.2 kB ? eta 0:00:00
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.

# %%
import pandas_datareader.data as pdr
import yfinance as yfin
yfin.pdr_override()

# %%
import datetime as dt
from datetime import datetime

# %%
ticker = "AAPL"
start = dt.datetime(2019,1,1)
end = dt.datetime(2020, 12, 31)

data = pdr.get_data_yahoo(ticker,start)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  38.047035  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.257282  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.719704  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.640198  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  36.319614  164101200

# %%
data.index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2023-03-08', '2023-03-09', '2023-03-10', '2023-03-13',
#                '2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17',
#                '2023-03-20', '2023-03-21'],
#               dtype='datetime64[ns]', name='Date', length=1062, freq=None)

# %%
data.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-03-15  151.190002  153.250000  149.919998  152.990005  152.990005
# 2023-03-16  152.160004  156.460007  151.639999  155.850006  155.850006
# 2023-03-17  156.080002  156.740005  154.279999  155.000000  155.000000
# 2023-03-20  155.070007  157.820007  154.149994  157.399994  157.399994
# 2023-03-21  157.320007  159.399994  156.539993  159.279999  159.279999
#
#               Volume
# Date
# 2023-03-15  77167900
# 2023-03-16  76161100
# 2023-03-17  98862500
# 2023-03-20  73641400
# 2023-03-21  73868900

# %%
data2 = pdr.get_data_yahoo(ticker,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data2.index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2020-12-16', '2020-12-17', '2020-12-18', '2020-12-21',
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-28',
#                '2020-12-29', '2020-12-30'],
#               dtype='datetime64[ns]', name='Date', length=504, freq=None)

# %%
data2.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  129.209274
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.205765
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.862686
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.067032
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.932388
#
#                Volume
# Date
# 2020-12-23   88223700
# 2020-12-24   54930100
# 2020-12-28  124486200
# 2020-12-29  121047300
# 2020-12-30   96452100

# %%
data3 = pdr.get_data_stooq(ticker,start)

# %%
data3.head()
# Out:
#               Open     High     Low   Close      Volume
# Date
# 2023-03-21  157.32  159.400  156.54  159.28  73938285.0
# 2023-03-20  155.07  157.820  154.15  157.40  73641415.0
# 2023-03-17  156.08  156.740  154.28  155.00  98944633.0
# 2023-03-16  152.16  156.460  151.64  155.85  76254419.0
# 2023-03-15  151.19  153.245  149.92  152.99  77167866.0

# %%
data3.tail()
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2019-01-08  36.0899  36.6342  35.8367  36.3711  1.700222e+08
# 2019-01-07  35.8786  35.9104  35.2046  35.6911  2.270168e+08
# 2019-01-04  34.8746  35.8446  34.6991  35.7729  2.428866e+08
# 2019-01-03  34.7431  35.1588  34.2635  34.3094  3.784272e+08
# 2019-01-02  37.3770  38.3281  37.2125  38.1048  1.535046e+08

# %%
nasdaq_sym = pdr.get_nasdaq_symbols()

# %%
nasdaq_sym
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Investment Managers Series Trust II AXS First ...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXYZ.A           True                 Nasdaq Symbology Test Common Stock
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZYME             True                      Zymeworks Inc. - Common Stock
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %%
nasdaq_sym.loc['AAPL']
# Out:
# Nasdaq Traded                            True
# Security Name       Apple Inc. - Common Stock
# Listing Exchange                            Q
# Market Category                             Q
# ETF                                     False
# Round Lot Size                          100.0
# Test Issue                              False
# Financial Status                            N
# CQS Symbol                                NaN
# NASDAQ Symbol                            AAPL
# NextShares                              False
# Name: AAPL, dtype: object

# %%
len(nasdaq_sym)
# Out:
# 11613

# %%
nasdaq_sym.head()
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Investment Managers Series Trust II AXS First ...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# A                     N                  False           100.0       False
# AA                    N                  False           100.0       False
# AAA                   P                   True           100.0       False
# AAAU                  Z                   True           100.0       False
# AAC                   N                  False           100.0       False
#
# ...

# %%
nasdaq_sym.loc['GME']
# Out:
# Nasdaq Traded                                    True
# Security Name       GameStop Corporation Common Stock
# Listing Exchange                                    N
# Market Category
# ETF                                             False
# Round Lot Size                                  100.0
# Test Issue                                      False
# Financial Status                                  NaN
# CQS Symbol                                        GME
# NASDAQ Symbol                                     GME
# NextShares                                      False
# Name: GME, dtype: object

# %%
ticker_gme = "GME"
start = dt.datetime(2019,1,1)
end = dt.datetime(2020, 12, 31)

data_gme = pdr.get_data_yahoo(ticker_gme,start)
data_gme_stooq = pdr.get_data_stooq(ticker_gme,start)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_gme.head()
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-01-02  3.1125  3.2950  3.1050  3.2675   3.160276   8496800
# 2019-01-03  3.2450  3.3150  3.1725  3.2425   3.136097   7001600
# 2019-01-04  3.5075  3.8225  3.4250  3.8100   3.684974  47662800
# 2019-01-07  3.7775  3.9525  3.7350  3.8700   3.743005  18872000
# 2019-01-08  3.8750  3.9725  3.7875  3.9525   3.822798  13775200

# %%
data_gme.index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2023-03-08', '2023-03-09', '2023-03-10', '2023-03-13',
#                '2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17',
#                '2023-03-20', '2023-03-21'],
#               dtype='datetime64[ns]', name='Date', length=1062, freq=None)

# %%
data_gme.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-03-15  16.500000  16.690001  15.700000  15.950000  15.950000   4541500
# 2023-03-16  16.000000  16.770000  15.530000  16.760000  16.760000   4083000
# 2023-03-17  16.620001  16.719999  15.920000  16.600000  16.600000   5092100
# 2023-03-20  16.650000  17.270000  16.250000  16.870001  16.870001   4463700
# 2023-03-21  17.150000  18.350000  17.139999  17.650000  17.650000  13613500

# %%
data_gme.min()
# Out:
# Open         7.125000e-01
# High         7.350000e-01
# Low          6.425000e-01
# Close        7.000000e-01
# Adj Close    7.000000e-01
# Volume       1.122700e+06
# dtype: float64

# %%
data_gme['Close'].argmin()
# Out:
# 316

# %%
data_gme.iloc[316:]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-04-03   0.712500   0.735000   0.642500   0.700000   0.700000  15321600
# 2020-04-06   0.715000   0.800000   0.707500   0.772500   0.772500  13362000
# 2020-04-07   0.847500   0.860000   0.775000   0.817500   0.817500  11347600
# 2020-04-08   0.807500   0.917500   0.800000   0.852500   0.852500  11538000
# 2020-04-09   0.900000   1.062500   0.872500   0.972500   0.972500  23634400
# ...               ...        ...        ...        ...        ...       ...
# 2023-03-15  16.500000  16.690001  15.700000  15.950000  15.950000   4541500
# 2023-03-16  16.000000  16.770000  15.530000  16.760000  16.760000   4083000
# 2023-03-17  16.620001  16.719999  15.920000  16.600000  16.600000   5092100
# 2023-03-20  16.650000  17.270000  16.250000  16.870001  16.870001   4463700
# 2023-03-21  17.150000  18.350000  17.139999  17.650000  17.650000  13613500
#
# [746 rows x 6 columns]

# %%
nasdaq_sym.groupby('Financial Status').count()
# Out:
#                   Nasdaq Traded  Security Name  Listing Exchange  \
# Financial Status
# D                           477            477               477
# E                            13             13                13
# H                            11             11                11
# N                          4848           4848              4848
#
#                   Market Category   ETF  Round Lot Size  Test Issue  \
# Financial Status
# D                             477   477             477         477
# E                              13    13              13          13
# H                              11    11              11          11
# N                            4848  4848            4848        4848
#
#                   CQS Symbol  NASDAQ Symbol  NextShares
# Financial Status
# D                          0            477         477
# E                          0             13          13
# H                          0             11          11
# ...

# %%
nasdaq_sym.groupby('Financial Status').count()

# %%
dataset = nasdaq_sym[nasdaq_sym['Financial Status'] == 'D']

# %%
dataset.head()
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# ABVC             True                ABVC BioPharma, Inc. - Common Stock
# ACBA             True  Ace Global Business Acquisition Limited - Ordi...
# ACON             True                      Aclarion, Inc. - Common Stock
# ACONW            True                           Aclarion, Inc. - Warrant
# ACOR             True           Acorda Therapeutics, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# ABVC                  Q               S  False           100.0       False
# ACBA                  Q               S  False           100.0       False
# ACON                  Q               S  False           100.0       False
# ACONW                 Q               S  False           100.0       False
# ACOR                  Q               Q  False           100.0       False
#
# ...

# %%
dataset.tail()
# Out:
#         Nasdaq Traded                                     Security Name  \
# Symbol
# YVR              True           Liquid Media Group Ltd. - Common Shares
# ZIVO             True              Zivo Bioscience, Inc. - Common Stock
# ZIVOW            True                  Zivo Bioscience, Inc. - Warrants
# ZKIN             True  ZK International Group Co., Ltd - Ordinary Share
# ZYNE             True      Zynerba Pharmaceuticals, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# YVR                   Q               S  False           100.0       False
# ZIVO                  Q               S  False           100.0       False
# ZIVOW                 Q               S  False           100.0       False
# ZKIN                  Q               S  False           100.0       False
# ZYNE                  Q               G  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# ...
