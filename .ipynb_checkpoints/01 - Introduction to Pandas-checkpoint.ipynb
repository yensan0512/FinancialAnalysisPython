# %% [markdown]
# # Introduction to DataFrames
# - Read data from CSV (downloadable from Yahoo! Finance)
# - Understand data types
# - Set index
# - Parse dates
# - Use index with **loc**
# - Use indexing with **iloc**

# %%
import pandas as pd

# %%
remote_file = "https://raw.githubusercontent.com/LearnPythonWithRune/FinancialDataAnalysisWithPython/main/files/AAPL.csv"
test = pd.read_csv(remote_file, index_col=0, parse_dates=True)

# %%
data = pd.read_csv('AAPL.csv')

# %%
data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187
# 1  2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477
# 2  2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747
# 3  2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246
# 4  2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989
#
#       Volume
# 0  161940000
# 1  162234000
# 2  216229200
# 3  126743200
# 4  199588400

# %%
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=253, step=1)

# %%
data2 = pd.read_csv('AAPL.csv',index_col=0,parse_dates=True)

# %%
data2.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400

# %%
data2.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data2.index
# Out:
# DatetimeIndex(['2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30',
#                '2020-01-31', '2020-02-03', '2020-02-04', '2020-02-05',
#                '2020-02-06', '2020-02-07',
#                ...
#                '2021-01-12', '2021-01-13', '2021-01-14', '2021-01-15',
#                '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22',
#                '2021-01-25', '2021-01-26'],
#               dtype='datetime64[ns]', name='Date', length=253, freq=None)

# %%
data2.loc['2020-01-27']
# Out:
# Open         7.751500e+01
# High         7.794250e+01
# Low          7.622000e+01
# Close        7.723750e+01
# Adj Close    7.657619e+01
# Volume       1.619400e+08
# Name: 2020-01-27 00:00:00, dtype: float64

# %%
data2.loc['2021-01-01':]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  129.410004
# 2021-01-05  128.889999  131.740005  128.429993  131.009995  131.009995
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  126.599998
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  130.919998
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  132.050003
# 2021-01-11  129.190002  130.169998  128.500000  128.979996  128.979996
# 2021-01-12  128.500000  129.690002  126.860001  128.800003  128.800003
# 2021-01-13  128.759995  131.449997  128.490005  130.889999  130.889999
# 2021-01-14  130.800003  131.000000  128.759995  128.910004  128.910004
# 2021-01-15  128.779999  130.220001  127.000000  127.139999  127.139999
# 2021-01-19  127.779999  128.710007  126.940002  127.830002  127.830002
# 2021-01-20  128.660004  132.490005  128.550003  132.029999  132.029999
# ...

# %%
data2.loc['2020-06-01':'2020-07-01']
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-06-01  79.437500  80.587502  79.302498  80.462502  80.179359   80791200
# 2020-06-02  80.187500  80.860001  79.732498  80.834999  80.550545   87642800
# 2020-06-03  81.165001  81.550003  80.574997  81.279999  80.993980  104491200
# 2020-06-04  81.097504  81.404999  80.195000  80.580002  80.296448   87560400
# 2020-06-05  80.837502  82.937500  80.807503  82.875000  82.583374  137250400
# 2020-06-08  82.562500  83.400002  81.830002  83.364998  83.071640   95654400
# 2020-06-09  83.035004  86.402496  83.002502  85.997498  85.694878  147712400
# 2020-06-10  86.974998  88.692497  86.522499  88.209999  87.899590  166651600
# 2020-06-11  87.327499  87.764999  83.870003  83.974998  83.679497  201662400
# 2020-06-12  86.180000  86.949997  83.555000  84.699997  84.401947  200146000
# 2020-06-15  83.312500  86.419998  83.144997  85.747498  85.445755  138808800
# ...

# %%
# filter data until 2020-07-01
data2.loc[:'2020-07-01']
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-27  77.514999  77.942497  76.220001  77.237503  76.576187  161940000
# 2020-01-28  78.150002  79.599998  78.047501  79.422501  78.742477  162234000
# 2020-01-29  81.112503  81.962502  80.345001  81.084999  80.390747  216229200
# 2020-01-30  80.135002  81.022499  79.687500  80.967499  80.274246  126743200
# 2020-01-31  80.232498  80.669998  77.072502  77.377502  76.714989  199588400
# ...               ...        ...        ...        ...        ...        ...
# 2020-06-25  90.175003  91.250000  89.392502  91.209999  90.889038   34380600
# 2020-06-26  91.102501  91.330002  88.254997  88.407501  88.096405   51314200
# 2020-06-29  88.312500  90.542503  87.820000  90.445000  90.126732   32661500
# 2020-06-30  90.019997  91.495003  90.000000  91.199997  90.879066   35055800
# 2020-07-01  91.279999  91.839996  90.977501  91.027496  90.707176   27684300
#
# [110 rows x 6 columns]

# %%
# first data
data.iloc[0]
# Out:
# Date         2020-01-27
# Open          77.514999
# High          77.942497
# Low           76.220001
# Close         77.237503
# Adj Close     76.576187
# Volume        161940000
# Name: 0, dtype: object

# %%
# get last data
data.iloc[-1]
# Out:
# Date         2021-01-26
# Open         143.600006
# High         144.300003
# Low          141.369995
# Close        142.080002
# Adj Close    142.080002
# Volume         50388565
# Name: 252, dtype: object

# %%
data.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 248  2021-01-20  128.660004  132.490005  128.550003  132.029999  132.029999
# 249  2021-01-21  133.800003  139.669998  133.589996  136.869995  136.869995
# 250  2021-01-22  136.279999  139.850006  135.020004  139.070007  139.070007
# 251  2021-01-25  143.070007  145.089996  136.539993  142.919998  142.919998
# 252  2021-01-26  143.600006  144.300003  141.369995  142.080002  142.080002
#
#         Volume
# 248  104319500
# 249  120529500
# 250  114459400
# 251  157282400
# 252   50388565
